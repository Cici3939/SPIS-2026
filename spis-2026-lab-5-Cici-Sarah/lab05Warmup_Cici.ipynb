# %% [markdown]
# <a href="https://colab.research.google.com/github/ucsd-cse-spis-2026/spis-2026-lab-5-Cici-Sarah/blob/main/lab05Warmup_Cici.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
bear = Image.open("bear.png")
display(bear)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x800>

# %%
bear.save("new_bear.png") # create/overwrite new_bear.png with current image

# %%
print(bear.size)
# Out:
# (600, 800)

# %%
pixel = bear.getpixel( ( 100, 200) )
print(pixel)
# Out:
# (166, 201, 239)

# %%
for i in range(100):

    bear.putpixel( (i, 200) , (0, 0, 0) )
display(bear)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x800>

# %%
def invert( im ):
    ''' Invert the colors in the input image, im '''

    # Find the dimensions of the image
    (width, height) = im.size

    # Loop over the entire image
    for x in range( width ):
        for y in range( height ):
            (red, green, blue) = im.getpixel((x, y))
            # Complete this function by adding your lines of code here.
            # You need to calculate the new pixel values and then to change them
            # in the image using putpixel()
            im.putpixel( (x,y), (255-red, 255-green, 255-blue))

invert(bear)
display(bear)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x800>

# %%
def invert_block( im ):
  ''' Invert the colors on the upper right quadrant in the input image, im '''

  # Find the dimensions of the image
  (width, height) = im.size

  # Loop over the entire image
  for x in range( width//2, width ):
      for y in range( height//2 ):
          (red, green, blue) = im.getpixel((x, y))
          # Complete this function by adding your lines of code here.
          # You need to calculate the new pixel values and then to change them
          # in the image using putpixel()
          im.putpixel( (x,y), (255-red, 255-green, 255-blue))

invert(bear)

invert_block(bear)
display(bear)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x800>
