# %% [markdown]
# <a href="https://colab.research.google.com/github/ucsd-cse-spis-2026/spis-2026-lab-3-Cici-Sarah/blob/main/lab03Letters_Cici_Sarah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
""""
 1. The "anonymous turtle" is a turtle object used if there is no turtle object created.
 One may call this by using the methods without an object.
 2. my_turtle is an instance of a Turtle, whereas the Turtle() constructor makes a turtle.
 3. my_turtle.sety(100)
 """

# %%
# !pip install ColabTurtlePlus

# %%
from ColabTurtlePlus.Turtle import *
# Out:
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell

# %%
def draw_C(the_turtle):
  # draw using .circle()
  the_turtle.left(135)
  the_turtle.penup()
  the_turtle.setpos(10,100) # xcor + something
  the_turtle.pendown()

  the_turtle.circle(100, 270)
  the_turtle.penup()
  the_turtle.setpos(60, 100)

def draw_I(the_turtle):
  # draw line
  the_turtle.left(135)
  the_turtle.penup()
  the_turtle.setpos(10,100)
  the_turtle.pendown()

  the_turtle.circle(100, 270)



clearscreen()
turt = Turtle()

turt.speed(5)
draw_C(turt)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 410.0 200.0 A 100 100 0 0 0 389.289 184.108" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 389.289 184.108 A 100 100 0 0 0 365.171 174.118" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 365.171 174.118 A 100 100 0 0 0 339.289 170.711" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 339.289 170.711 A 100 100 0 0 0 313.407 174.118" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 313.407 174.118 A 100 100 0 0 0 289.289 184.108" stroke-linecap="round"
# ...
