# %% [markdown]
# <a href="https://colab.research.google.com/github/ucsd-cse-spis-2026/spis-2026-lab-0-cicixing3939/blob/main/notebook_spis26_lab00_Cici_X.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cici Xing for SPIS 2026

print('Hello, World!')

print('Hello, you!')
# Out:
# Hello, World!
# Hello, you!
